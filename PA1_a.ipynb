# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm

# %%
#According to Part A question 1 there are 20 features and 2000 samples in the distribution
features = 20
n = 2000

# %%
#Finding the mean of the distribution
def dist_mean(n):
    return np.random.rand(n)

#Finding the covariance of the distribution
def dist_covar(n):
    A= np.random.rand(n,n)
    covariance = np.dot(A, A.transpose())
    return A

# %%
#Calculating the means of 2 classes
mean_0 = dist_mean(features)
mean_1 = mean_0 +5* dist_mean(features)


#Covariance matrix of 2 classes
covar = dist_covar(features)

print("Covariance matrix ::::::\n" , covar)
# Out:
# Covariance matrix ::::::
#  [[0.65294867 0.33634459 0.1397832  0.25378631 0.83438801 0.0746123
#   0.77820186 0.58700995 0.96260968 0.34577523 0.13551462 0.21778364
#   0.40779405 0.84901741 0.3068198  0.53088645 0.08828446 0.2220385
#   0.99825118 0.93936762]
#  [0.94926771 0.75387892 0.76220556 0.70647238 0.71056006 0.01204165
#   0.58333893 0.11697704 0.1885052  0.68767113 0.57278093 0.93737492
#   0.23262646 0.16687116 0.59539203 0.84374193 0.42808039 0.86984199
#   0.92458306 0.96070096]
#  [0.41768313 0.10378649 0.56197563 0.96658405 0.05274307 0.72644538
#   0.21154895 0.7042022  0.44267592 0.04948722 0.6768738  0.82155215
#   0.87967951 0.79684058 0.49505175 0.2867786  0.18861395 0.6569121
#   0.20402007 0.44649784]
#  [0.45562868 0.79974039 0.77316483 0.30039363 0.66138057 0.12052724
#   0.6811599  0.08591852 0.09364737 0.48244449 0.72345172 0.85103863
#   0.95716575 0.64227816 0.74242509 0.94720585 0.54819381 0.48808136
#   0.15732465 0.84071723]
#  [0.616597   0.89708218 0.4332648  0.15465208 0.25577245 0.11862376
#   0.40833115 0.17342128 0.65876323 0.68960114 0.39450012 0.75192395
#   0.7593771  0.62468324 0.48300078 0.58302384 0.74392723 0.84644806
#   0.89022312 0.05325277]
#  [0.47696238 0.06346758 0.35295005 0.52232932 0.80729788 0.17138475
#   0.31896288 0.86049114 0.6042271  0.98181795 0.47103756 0.95443655
#   0.06891021 0.32913694 0.83705415 0.61546684 0.52574271 0.57293675
#   0.8830697  0.44303963]
#  [0.00203735 0.25660814 0.81557036 0.6006575  0.37162059 0.23631424
#   0.81785163 0.40972822 0.55570844 0.29257148 0.4394515  0.34727249
#   0.12515374 0.73509772 0.13265746 0.90723444 0.07733777 0.41541692
#   0.15710999 0.47228939]
#  [0.94571397 0.98332188 0.88177329 0.95094574 0.8319821  0.9020373
#   0.82347217 0.91055342 0.91860504 0.5559622  0.76737416 0.12364594
#   0.94334119 0.09522284 0.52664138 0.81104099 0.25979994 0.47646955
#   0.40226341 0.25327143]
#  [0.72566059 0.00264925 0.05691059 0.41061413 0.2994798  0.07875534
#   0.7096696  0.87279461 0.11174097 0.12483099 0.14568255 0.16881852
#   0.77218483 0.98780988 0.98544743 0.71264366 0.70546061 0.91666394
#   0.50347184 0.10105934]
#  [0.17798231 0.89938048 0.86396748 0.29366894 0.55797008 0.45547799
#   0.78353759 0.48995409 0.42606937 0.59467346 0.20349264 0.53686128
#   0.41856375 0.88926052 0.51328261 0.31360261 0.81309491 0.54115845
#   0.68133688 0.7292333 ]
#  [0.33278102 0.59463556 0.1958589  0.64677785 0.48754421 0.64102557
#   0.1612321  0.19162204 0.56037068 0.8547916  0.09675768 0.06748483
#   0.39200654 0.42776645 0.83993346 0.5033778  0.38083388 0.47386782
#   0.12304156 0.79388101]
#  [0.84734686 0.70937842 0.75302819 0.91012106 0.81120807 0.59964727
#   0.95572898 0.7603372  0.89670996 0.22544177 0.6389986  0.29247274
#   0.29730924 0.99296853 0.81302286 0.98595097 0.10544445 0.32420077
#   0.83564056 0.71272318]
#  [0.90084436 0.42319728 0.79452457 0.27390744 0.67097666 0.90595815
#   0.24725552 0.85694693 0.08723743 0.47888322 0.42225381 0.86145648
#   0.46658499 0.82786966 0.07176901 0.64987308 0.24399595 0.30708866
#   0.2189342  0.35259148]
#  [0.93358332 0.7202244  0.76728169 0.12396645 0.87348085 0.6886829
#   0.53749671 0.68185    0.36529489 0.66331053 0.61242866 0.79773039
#   0.70722795 0.75999108 0.74830455 0.38711654 0.4101785  0.16265541
#   0.14230892 0.88766923]
#  [0.0174022  0.54622534 0.28127377 0.63996713 0.57752715 0.53940943
#   0.39944985 0.09598265 0.63663571 0.87437372 0.26386521 0.85220238
#   0.39013449 0.78903857 0.74168638 0.63197693 0.80257458 0.8237799
#   0.94186947 0.60824096]
#  [0.53217888 0.94824056 0.61905183 0.34026587 0.92974782 0.51867889
#   0.63175242 0.53412753 0.43136693 0.60987045 0.89562849 0.80532867
#   0.02855241 0.62601787 0.93043659 0.03799034 0.57929705 0.10559639
#   0.66287133 0.08339195]
#  [0.49211123 0.10480333 0.19796544 0.07163295 0.75516317 0.62038631
#   0.4932186  0.26071794 0.71416251 0.20013525 0.77633911 0.85371392
#   0.07277059 0.32578241 0.226317   0.00714046 0.89207663 0.10193654
#   0.82384938 0.77485363]
#  [0.75545476 0.18528811 0.38206372 0.77853032 0.57853669 0.30261871
#   0.98014523 0.140405   0.06721805 0.97221133 0.54433368 0.37540914
#   0.98397651 0.56333522 0.46336381 0.26760434 0.24987118 0.97810585
#   0.23539954 0.60331606]
#  [0.41825651 0.5433042  0.51620386 0.374771   0.94815556 0.78285368
#   0.89623436 0.47419891 0.02601369 0.05314424 0.57557726 0.81267516
#   0.13745805 0.00245686 0.42534163 0.54460078 0.86911914 0.85091102
#   0.06290743 0.93393113]
#  [0.17350705 0.50833561 0.28695962 0.57529995 0.05984052 0.87226204
#   0.8975565  0.61364204 0.94596836 0.1821457  0.88875634 0.85149891
#   0.36386806 0.75540115 0.72078642 0.16121493 0.63932457 0.63717191
#   0.80245423 0.92055333]]

# %%
#Obtain the multivariate distribution for class 0 & 1
class_0 = np.random.multivariate_normal(mean_0, covar, n)
class_1 = np.random.multivariate_normal(mean_1, covar, n)

#Plot both classes to show the overlap
plt.scatter(class_0[:,0], class_0[:,1], color ='green')
plt.scatter(class_1[:,0], class_1[:,1], color = 'red')

plt.show()
# Out:
# C:\Users\abarat\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: covariance is not symmetric positive-semidefinite.
#
# C:\Users\abarat\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: covariance is not symmetric positive-semidefinite.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
from sklearn.model_selection import train_test_split

X = np.random.rand(n, features)
y = np.array([[1 for _ in range(int(n/2)) ], [0 for _ in range(int (n/2))]]). ravel()
Xtrain, Xtest, ytrain, ytest = train_test_split(X, y , test_size = 0.3 , random_state =10)

print(Xtrain.shape , Xtest.shape)
print(ytrain.shape , ytest.shape)
# Out:
# (1400, 20) (600, 20)
# (1400,) (600,)
